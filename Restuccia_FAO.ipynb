# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# pd.set_option('display.float_format', lambda x: '%.5f' % x)
# pd.options.display.float_format = '{:,.2f}'.format

pd.set_option('display.expand_frame_repr', False)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.options.display.float_format = '{:,.2f}'.format

# %%
fao_data = pd.read_csv("/users/quasar/downloads/FAOSTAT_data_4-15-2022.csv")
fao = pd.read_csv("/users/quasar/downloads/FAOSTAT_data_4-15-2022-2.csv")
restuccia = pd.read_excel("/users/quasar/downloads/RYZ_data.xls")
pwt = pd.read_stata("/users/quasar/downloads/pwt100.dta")
pwt_labour = pd.read_stata("/users/quasar/downloads/pwt100-labor-detail.dta")

# %%
fao_data.Item.unique()
# Out:
# array(['Nutrient nitrogen N (total)', 'Nutrient phosphate P2O5 (total)',
#        'Nutrient potash K2O (total)'], dtype=object)

# %%
fao_data.head(5)
# Out:
#   Domain Code                   Domain  Area Code   Area  Element Code           Element  Item Code                             Item  Year Code  Year    Unit   Value Flag                                   Flag Description
# 0         RFN  Fertilizers by Nutrient        100  India          5157  Agricultural Use       3102      Nutrient nitrogen N (total)       1961  1961  tonnes  249800   Qm  Official data from questionnaires and/or natio...
# 1         RFN  Fertilizers by Nutrient        100  India          5157  Agricultural Use       3103  Nutrient phosphate P2O5 (total)       1961  1961  tonnes   60500   Qm  Official data from questionnaires and/or natio...
# 2         RFN  Fertilizers by Nutrient        100  India          5157  Agricultural Use       3104      Nutrient potash K2O (total)       1961  1961  tonnes   28000   Qm  Official data from questionnaires and/or natio...
# ...

# %%
fao.head()
# Out:
#   Domain Code    Domain  Area Code   Area  Element Code Element  Item Code                                   Item  Year Code  Year     Unit   Value Flag                                   Flag Description
# 0          RL  Land Use        100  India          5110    Area       6621                            Arable land       1961  1961  1000 ha  155806    Q  Official data reported on FAO Questionnaires f...
# 1          RL  Land Use        100  India          5110    Area       6650             Land under permanent crops       1961  1961  1000 ha    5180    Q  Official data reported on FAO Questionnaires f...
# 2          RL  Land Use        100  India          5110    Area       6655  Land under perm. meadows and pastures       1961  1961  1000 ha   13966    W  Data reported on country official publications...
# ...

# %%
restuccia
# Out:
#     Unnamed: 0         Country Code  SH#  GDP/N   GDPn/Ln   GDPa/La     Ya/La  X/Ya  La/N  Z/N    pi  ronetheta
# 0            1  ALGERIA         DZA    1  13434 17,999.24    891.54  1,154.10  0.23  0.27 1.55  1.02       0.28
# 1            2  ANGOLA          AGO    2   1742  6,406.03    168.13    198.58  0.15  0.75 0.95  2.13       0.08
# 2            3  ARGENTINA       ARG   73  14955 15,743.43  9,024.67 12,581.45  0.28  0.12 2.52  1.28       0.72
# 3            4  AUSTRALIA       AUS  145  28960 29,502.58 20,226.89 28,641.87  0.29  0.06 6.39  1.47       1.04
# 4            5  AUSTRIA         AUT  116  23837 25,208.09  6,164.67  9,357.42  0.34  0.07 0.43  1.45       0.58
# 5            6  BANGLADESH      BGD   86   4265 14,505.59    243.99    288.68  0.15  0.72 0.32  4.71       0.21
# 6            7  BELGIUM         BEL  117  27325 27,639.42 13,952.93 27,877.98  0.50  0.02 0.19  1.15       1.54
# ...

# %%
pwt.loc[(pwt.country=='India') & (pwt.year == 1985)]
# Out:
#      countrycode country currency_unit  year      rgdpe      rgdpo    pop    emp      avh   hc       ccon        cda      cgdpe      cgdpo           cn   ck  ctfp  cwtfp       rgdpna       rconna        rdana         rnna  rkna  rtfpna  rwtfpna  labsh  irr  delta    xr  pl_con  pl_da  pl_gdpo      i_cig       i_xm          i_xr i_outlier    i_irr  cor_exp  statcap  csh_c  csh_i  csh_g  csh_x  csh_m  csh_r  pl_c  pl_i  pl_g  pl_x  pl_m  pl_n  pl_k
# 5495         IND   India  Indian Rupee  1985 914,695.38 929,310.62 784.36 302.80 2,068.61 1.38 860,951.12 991,319.88 933,463.50 945,219.12 1,983,833.75 0.06  0.30   0.30 1,184,155.00 1,055,980.00 1,147,827.50 4,784,622.00  0.11    0.65     0.62   0.70 0.06   0.04 12.37    0.22   0.25     0.24  Benchmark  Benchmark  Market-based   Regular  Regular     0.38      NaN   0.72   0.14   0.19   0.03  -0.05  -0.03  0.25  0.39  0.14  0.35  0.38  0.28  0.66

# %%
pwt_labour.loc[pwt_labour.countrycode=='IND'].tail(10)
# Out:
#      countrycode     year            emp      avh               i_emp  yr_sch     source  labsh                    i_labsh                          i_labsh2  comp_sh  lab_sh1  lab_sh2  lab_sh3  lab_sh4                         i_comp_sh i_lab_sh1 i_lab_sh2                         i_lab_sh3                         i_lab_sh4
# 5228         IND 2,010.00 467,412,512.00 2,110.39      ETD (official)    5.39  Barro-Lee   0.51  Adjustment 4, agriculture                     Observed data     0.33      NaN      NaN     0.66     0.51                     Observed data       NaN       NaN                     Observed data                     Observed data
# 5229         IND 2,011.00 472,214,464.00 2,113.62      ETD (official)    5.50  Barro-Lee   0.51  Adjustment 4, agriculture                     Observed data     0.33      NaN      NaN     0.67     0.51                     Observed data       NaN       NaN                     Observed data                     Observed data
# ...
